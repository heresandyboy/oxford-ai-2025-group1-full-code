# %% [markdown]
# <a href="https://colab.research.google.com/github/Rraj025/2025_Capstone_AIproject/blob/main/Capstone_project_AI_summit_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#installing the various packages
# !pip install openai-agents
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.6/130.6 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.3/129.3 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.9/150.9 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.0 MB/s eta 0:00:00
# ...

# %%
#downloading the synthetic dataset
import pandas as pd

url = "https://raw.githubusercontent.com/Rraj025/2025_Capstone_AIproject/refs/heads/main/final_customer_location_aligned.csv"
data = pd.read_csv(url)
data.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Order quantities  \
# 0        8661.996792            Non-binary            58                96
# 1        7460.900065                Female            53                37
# 2        9577.749626               Unknown             1                88
# 3        7766.836426            Non-binary            23                59
# 4        2686.505152            Non-binary             5                56
#
#    Shipping times  ... Supplier name  Location Production volumes  \
# ...
